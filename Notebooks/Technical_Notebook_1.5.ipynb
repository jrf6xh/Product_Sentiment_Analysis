# %%
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
import nltk
from nltk.corpus import stopwords
import string
from nltk import word_tokenize, FreqDist
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB

# %%
df = pd.read_csv('../Data/data.csv', encoding='latin-1')
df.rename(columns={'emotion_in_tweet_is_directed_at':'object', 'is_there_an_emotion_directed_at_a_brand_or_product':'sentiment'}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9093 entries, 0 to 9092
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_text  9092 non-null   object
#  1   object      3291 non-null   object
#  2   sentiment   9093 non-null   object
# dtypes: object(3)
# memory usage: 213.2+ KB

# %% [markdown]
# Remove row with missing text data.

# %%
df.dropna(thresh=2, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9092 entries, 0 to 9092
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_text  9092 non-null   object
#  1   object      3291 non-null   object
#  2   sentiment   9092 non-null   object
# dtypes: object(3)
# memory usage: 284.1+ KB

# %%
df.head()
# Out:
#                                           tweet_text              object  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs twe...              iPhone
# 1  @jessedee Know about @fludapp ? Awesome iPad/i...  iPad or iPhone App
# 2  @swonderlin Can not wait for #iPad 2 also. The...                iPad
# 3  @sxsw I hope this year's festival isn't as cra...  iPad or iPhone App
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa M...              Google
#
#           sentiment
# 0  Negative emotion
# 1  Positive emotion
# 2  Positive emotion
# 3  Negative emotion
# 4  Positive emotion

# %%
df['sentiment'].value_counts()
# Out:
# No emotion toward brand or product    5388
# Positive emotion                      2978
# Negative emotion                       570
# I can't tell                           156
# Name: sentiment, dtype: int64

# %%
df['sentiment'].replace("I can't tell", "Unknown", inplace=True)
df['sentiment'].replace("No emotion toward brand or product", "None", inplace=True)
df['sentiment'].replace(" emotion", "", inplace=True)
df['sentiment'].value_counts()
# Out:
# None                5388
# Positive emotion    2978
# Negative emotion     570
# Unknown              156
# Name: sentiment, dtype: int64

# %%
df.head()
# Out:
#                                           tweet_text              object  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs twe...              iPhone
# 1  @jessedee Know about @fludapp ? Awesome iPad/i...  iPad or iPhone App
# 2  @swonderlin Can not wait for #iPad 2 also. The...                iPad
# 3  @sxsw I hope this year's festival isn't as cra...  iPad or iPhone App
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa M...              Google
#
#           sentiment
# 0  Negative emotion
# 1  Positive emotion
# 2  Positive emotion
# 3  Negative emotion
# 4  Positive emotion

# %%
X = df[['tweet_text', 'object']]
y = df['sentiment']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=18, stratify=y)

# %%
X_train.reset_index(inplace=True)
X_train.drop('index', axis=1, inplace=True)
X_test.reset_index(inplace=True)
X_test.drop('index', axis=1, inplace=True)
# Out:
# /Users/jamesfay/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# ## Remove Stopwords

# %%
#Create List of stopwords & punctuation
stopwords_list = stopwords.words('english') + list(string.punctuation)
stopwords_list += ["''", '""', '...', '``']

# %% [markdown]
# The '@' and '#' symbols carry special meaning in text on twitter and other social media platforms.  To include this meaning in the analysis, we'll remove these characters from the stopwords list.  The dataset also includes '{link}' in place of any actual url links.  We'll leave '{' and '}' in the text to reflect this.

# %%
stopwords_list.remove('#')
stopwords_list.remove('@')
stopwords_list.remove('{')
stopwords_list.remove('}')

# %%
def remove_stopwords(text):
    tokens = nltk.word_tokenize(text)
    stopwords_removed = [token.lower() for token in tokens if token.lower() not in stopwords_list]
    return stopwords_removed

# %%
processed = list(map(remove_stopwords, X_train['tweet_text']))

# %%
joined_text_list = []
for word_list in processed:
    joined_text = ' '.join(word_list)
    joined_text_list.append(joined_text)
joined_text_list[:5]
# Out:
# ['ipad2 3 weeks w ipad since gave @ mention # sxsw withdrawal',
#  'rt @ mention first shots w/ipad 2 # sxsw { link }',
#  "rt @ mention ning amp mobile roadie thrilled offer unofficial # sxsw insider 's guide iphone fun austin { link }",
#  "rt @ mention bounced catch google 's marissa mayer speak always admired intelligent classy successful # sxsw",
#  'part journalsim support democracy yes informed populous yes ipad focus support # newsapps # sxsw']

# %%
X_train['processed_text'] = joined_text_list
# Out:
# /Users/jamesfay/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_text      6819 non-null   object
#  1   object          2467 non-null   object
#  2   processed_text  6819 non-null   object
# dtypes: object(3)
# memory usage: 159.9+ KB

# %%
X_train.head()
# Out:
#                                           tweet_text object  \
# 0  No ipad2 for me. Now I have 3 weeks w no iPad ...    NaN
# 1  RT @mention First shots w/iPad 2 from #sxsw {l...    NaN
# 2  RT @mention Ning &amp; Mobile Roadie are thril...    NaN
# 3  RT @mention Bounced over to catch Google's Mar...    NaN
# 4  Part of Journalsim is the support of democracy...   iPad
#
#                                       processed_text
# 0  ipad2 3 weeks w ipad since gave @ mention # sx...
# 1  rt @ mention first shots w/ipad 2 # sxsw { link }
# 2  rt @ mention ning amp mobile roadie thrilled o...
# 3  rt @ mention bounced catch google 's marissa m...
# 4  part journalsim support democracy yes informed...

# %% [markdown]
# ## TF-IDF Vectorization

# %%
vectorizer = TfidfVectorizer()
tf_idf_data_train = vectorizer.fit_transform(X_train['processed_text'])
tf_idf_data_train.shape
# Out:
# (6819, 8530)

# %% [markdown]
# 6.8k tweets with 8.5k unique words in the vocabulary.

# %% [markdown]
# ## RF Classifier

# %%
#Create pipeline
pipe_forest = Pipeline([('forest', RandomForestClassifier(random_state=70, n_jobs=-1, bootstrap=True))])

# %%
# Create the grid parameter
grid_forest = [{'forest__n_estimators': [200],
             'forest__max_depth': [1, 5, 25, 50],
             'forest__min_samples_split': [2, 5, 25], 
             'forest__min_samples_leaf': [1, 5, 25], 
             'forest__criterion': ['gini', 'entropy'],
             'forest__max_features': ['auto', 'sqrt', 'log2'],
             'forest__max_samples': [None, .2, .5, .8]
             }]

# Create the grid, with "pipe" as the estimator
gridsearch_forest = GridSearchCV(estimator=pipe_forest, 
                          param_grid=grid_forest,
                          scoring='accuracy',
                          return_train_score=True, #Include training results in cv_results
                          cv=3, #Use 3 folds in CV process
                          n_jobs=-1, #Use paralell computing
                          verbose=4) #Give updates on progress during fitting

# %%
gridsearch_forest.fit(tf_idf_data_train, y_train)
# Out:
# Fitting 3 folds for each of 864 candidates, totalling 2592 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   43.6s
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 597 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 866 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 1185 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 1552 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 1969 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 2434 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 2592 out of 2592 | elapsed: 13.0min finished
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('forest',
#                                         RandomForestClassifier(n_jobs=-1,
#                                                                random_state=70))]),
#              n_jobs=-1,
#              param_grid=[{'forest__criterion': ['gini', 'entropy'],
#                           'forest__max_depth': [1, 5, 25, 50],
#                           'forest__max_features': ['auto', 'sqrt', 'log2'],
#                           'forest__max_samples': [None, 0.2, 0.5, 0.8],
#                           'forest__min_samples_leaf': [1, 5, 25],
#                           'forest__min_samples_split': [2, 5, 25],
#                           'forest__n_estimators': [200]}],
#              return_train_score=True, scoring='accuracy', verbose=4)

# %%
gridsearch_forest.best_params_
# Out:
# {'forest__criterion': 'gini',
#  'forest__max_depth': 50,
#  'forest__max_features': 'auto',
#  'forest__max_samples': None,
#  'forest__min_samples_leaf': 1,
#  'forest__min_samples_split': 5,
#  'forest__n_estimators': 200}

# %%
gridsearch_forest_df = pd.DataFrame.from_dict(gridsearch_forest.cv_results_)
gridsearch_forest_df.sort_values(by=['mean_test_score'], ascending=False).head(20)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 361       7.114472      0.189051         0.178533        0.046561
# 325       7.917075      0.074119         0.143317        0.046349
# 360       7.832189      0.144521         0.143255        0.047762
# 324       8.283978      0.224978         0.142927        0.047153
# 362       5.887313      0.576168         0.178125        0.048393
# 326       6.987861      0.671505         0.176646        0.048612
# 352       7.261401      0.291828         0.178529        0.049368
# 388       7.006231      0.117164         0.142067        0.047635
# 387       7.104897      0.363592         0.143401        0.047068
# 351       7.262914      0.406968         0.212097        0.002764
# 389       6.105689      0.488059         0.178825        0.049290
# 353       6.454551      0.394945         0.176229        0.048760
# 792       7.651374      0.131183         0.177199        0.048037
# 756       9.748667      0.712692         0.176522        0.048519
# 343       5.319192      0.136713         0.145432        0.047903
# 379       5.453207      0.294246         0.144086        0.048424
# 757       9.558372      0.245124         0.212865        0.003380
# 793       7.598310      0.763491         0.213678        0.000359
# 378       5.487449      0.297110         0.175999        0.047525
# 342       5.352953      0.474559         0.211434        0.085032
#
#     param_forest__criterion param_forest__max_depth  \
# 361                    gini                      50
# 325                    gini                      50
# 360                    gini                      50
# 324                    gini                      50
# 362                    gini                      50
# 326                    gini                      50
# 352                    gini                      50
# 388                    gini                      50
# 387                    gini                      50
# 351                    gini                      50
# 389                    gini                      50
# 353                    gini                      50
# 792                 entropy                      50
# 756                 entropy                      50
# 343                    gini                      50
# 379                    gini                      50
# 757                 entropy                      50
# 793                 entropy                      50
# 378                    gini                      50
# 342                    gini                      50
#
#     param_forest__max_features param_forest__max_samples  \
# 361                       sqrt                      None
# 325                       auto                      None
# 360                       sqrt                      None
# 324                       auto                      None
# 362                       sqrt                      None
# 326                       auto                      None
# 352                       auto                       0.8
# 388                       sqrt                       0.8
# 387                       sqrt                       0.8
# 351                       auto                       0.8
# 389                       sqrt                       0.8
# 353                       auto                       0.8
# 792                       sqrt                      None
# 756                       auto                      None
# 343                       auto                       0.5
# 379                       sqrt                       0.5
# 757                       auto                      None
# 793                       sqrt                      None
# 378                       sqrt                       0.5
# 342                       auto                       0.5
#
#     param_forest__min_samples_leaf param_forest__min_samples_split  ...  \
# 361                              1                               5  ...
# 325                              1                               5  ...
# 360                              1                               2  ...
# 324                              1                               2  ...
# 362                              1                              25  ...
# 326                              1                              25  ...
# 352                              1                               5  ...
# 388                              1                               5  ...
# 387                              1                               2  ...
# 351                              1                               2  ...
# 389                              1                              25  ...
# 353                              1                              25  ...
# 792                              1                               2  ...
# 756                              1                               2  ...
# 343                              1                               5  ...
# 379                              1                               5  ...
# 757                              1                               5  ...
# 793                              1                               5  ...
# 378                              1                               2  ...
# 342                              1                               2  ...
#
#     split1_test_score split2_test_score  mean_test_score  std_test_score  \
# 361          0.641443          0.640123         0.641150        0.000748
# 325          0.641443          0.640123         0.641150        0.000748
# 360          0.642763          0.640123         0.639977        0.002337
# 324          0.642763          0.640123         0.639977        0.002337
# 362          0.638803          0.635284         0.637337        0.001496
# 326          0.638803          0.635284         0.637337        0.001496
# 352          0.637923          0.631324         0.635430        0.002926
# 388          0.637923          0.631324         0.635430        0.002926
# 387          0.635724          0.636164         0.634990        0.001360
# 351          0.635724          0.636164         0.634990        0.001360
# 389          0.636604          0.630444         0.633817        0.002548
# 353          0.636604          0.630444         0.633817        0.002548
# 792          0.631324          0.625605         0.630151        0.003338
# 756          0.631324          0.625605         0.630151        0.003338
# 343          0.631764          0.628685         0.630004        0.001295
# 379          0.631764          0.628685         0.630004        0.001295
# 757          0.630884          0.628245         0.629418        0.001097
# 793          0.630884          0.628245         0.629418        0.001097
# 378          0.625165          0.629564         0.627511        0.001808
# 342          0.625165          0.629564         0.627511        0.001808
#
#      rank_test_score  split0_train_score  split1_train_score  \
# 361                1            0.758689            0.756049
# 325                1            0.758689            0.756049
# 360                3            0.782446            0.778047
# 324                3            0.782446            0.778047
# 362                5            0.723053            0.719754
# 326                5            0.723053            0.719754
# 352                7            0.745491            0.742411
# 388                7            0.745491            0.742411
# 387                9            0.765728            0.760449
# 351                9            0.765728            0.760449
# 389               11            0.710515            0.708975
# 353               11            0.710515            0.708975
# 792               13            0.795425            0.790585
# 756               13            0.795425            0.790585
# 343               15            0.708095            0.710075
# 379               15            0.708095            0.710075
# 757               17            0.760889            0.761989
# 793               17            0.760889            0.761989
# 378               19            0.720414            0.724153
# 342               19            0.720414            0.724153
#
#      split2_train_score  mean_train_score  std_train_score
# 361            0.761989          0.758909         0.002430
# 325            0.761989          0.758909         0.002430
# 360            0.783326          0.781273         0.002309
# 324            0.783326          0.781273         0.002309
# 362            0.724373          0.722393         0.001943
# 326            0.724373          0.722393         0.001943
# 352            0.743731          0.743877         0.001262
# 388            0.743731          0.743877         0.001262
# 387            0.763528          0.763235         0.002165
# 351            0.763528          0.763235         0.002165
# 389            0.711395          0.710295         0.001000
# 353            0.711395          0.710295         0.001000
# 792            0.799824          0.795278         0.003773
# 756            0.799824          0.795278         0.003773
# 343            0.716674          0.711615         0.003668
# 379            0.716674          0.711615         0.003668
# 757            0.760449          0.761109         0.000648
# 793            0.760449          0.761109         0.000648
# 378            0.734052          0.726206         0.005754
# 342            0.734052          0.726206         0.005754
#
# [20 rows x 23 columns]

# %%
best_models = gridsearch_forest_df.loc[gridsearch_forest_df['rank_test_score'] < 6]
best_models

# %%
#Create pipeline - Lock in parameters based on previous model

#Remove entropy based on previous results
#auto & sqrt are the same according to docs
pipe_forest2 = Pipeline([('forest', RandomForestClassifier(random_state=70, n_jobs=-1, bootstrap=True, criterion='gini', max_features='sqrt'))])

# %%
# Create the grid parameter
grid_forest2 = [{'forest__n_estimators': [200],
             'forest__max_depth': [50, 75, 100],
             'forest__min_samples_split': [2, 5, 25], 
             'forest__min_samples_leaf': [1, 5, 25], 
             'forest__max_samples': [.2, .5, .8] #Remove option to use all samples in bootstrp.  To combat overfitting.
             }]

# Create the grid, with "pipe" as the estimator
gridsearch_forest2 = GridSearchCV(estimator=pipe_forest2, 
                          param_grid=grid_forest2,
                          scoring='accuracy',
                          return_train_score=True, #Include training results in cv_results
                          cv=3, #Use 3 folds in CV process
                          n_jobs=-1, #Use paralell computing
                          verbose=4) #Give updates on progress during fitting

# %%
gridsearch_forest2.fit(tf_idf_data_train, y_train)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   39.2s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 243 out of 243 | elapsed:  2.1min finished
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('forest',
#                                         RandomForestClassifier(max_features='sqrt',
#                                                                n_jobs=-1,
#                                                                random_state=70))]),
#              n_jobs=-1,
#              param_grid=[{'forest__max_depth': [50, 75, 100],
#                           'forest__max_samples': [0.2, 0.5, 0.8],
#                           'forest__min_samples_leaf': [1, 5, 25],
#                           'forest__min_samples_split': [2, 5, 25],
#                           'forest__n_estimators': [200]}],
#              return_train_score=True, scoring='accuracy', verbose=4)

# %%
gridsearch_forest2.best_params_
# Out:
# {'forest__max_depth': 100,
#  'forest__max_samples': 0.8,
#  'forest__min_samples_leaf': 1,
#  'forest__min_samples_split': 2,
#  'forest__n_estimators': 200}

# %%
gridsearch_forest_df2 = pd.DataFrame.from_dict(gridsearch_forest2.cv_results_)
gridsearch_forest_df2.sort_values(by=['mean_test_score'], ascending=False).head(20)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 72      11.390336      0.408708         0.143235        0.049102
# 74       9.036112      1.219510         0.177156        0.047008
# 73      10.733454      0.204149         0.180419        0.048814
# 46       7.740358      0.088100         0.111053        0.001586
# 45       8.464817      0.181826         0.142090        0.046208
# 47       7.299459      0.290567         0.178249        0.048391
# 64       8.980183      0.121701         0.211513        0.001281
# 63       9.259192      0.394029         0.211585        0.001459
# 65       7.163476      1.523602         0.211788        0.003740
# 37       6.856656      0.103250         0.177202        0.048550
# 36       6.848620      0.494542         0.180705        0.049729
# 19       5.796848      0.026280         0.108998        0.001118
# 18       6.024189      0.264917         0.143044        0.049017
# 38       6.132896      0.508736         0.210159        0.002714
# 20       6.212424      0.168280         0.176695        0.049019
# 10       5.087003      0.166717         0.177918        0.046920
# 9        4.894058      0.617938         0.142533        0.048299
# 54       3.826322      0.341199         0.176510        0.048308
# 11       4.866973      0.024610         0.176437        0.048460
# 56       3.889821      0.158808         0.177750        0.045772
#
#    param_forest__max_depth param_forest__max_samples  \
# 72                     100                       0.8
# 74                     100                       0.8
# 73                     100                       0.8
# 46                      75                       0.8
# 45                      75                       0.8
# 47                      75                       0.8
# 64                     100                       0.5
# 63                     100                       0.5
# 65                     100                       0.5
# 37                      75                       0.5
# 36                      75                       0.5
# 19                      50                       0.8
# 18                      50                       0.8
# 38                      75                       0.5
# 20                      50                       0.8
# 10                      50                       0.5
# 9                       50                       0.5
# 54                     100                       0.2
# 11                      50                       0.5
# 56                     100                       0.2
#
#    param_forest__min_samples_leaf param_forest__min_samples_split  \
# 72                              1                               2
# 74                              1                              25
# 73                              1                               5
# 46                              1                               5
# 45                              1                               2
# 47                              1                              25
# 64                              1                               5
# 63                              1                               2
# 65                              1                              25
# 37                              1                               5
# 36                              1                               2
# 19                              1                               5
# 18                              1                               2
# 38                              1                              25
# 20                              1                              25
# 10                              1                               5
# 9                               1                               2
# 54                              1                               2
# 11                              1                              25
# 56                              1                              25
#
#    param_forest__n_estimators  \
# 72                        200
# 74                        200
# 73                        200
# 46                        200
# 45                        200
# 47                        200
# 64                        200
# 63                        200
# 65                        200
# 37                        200
# 36                        200
# 19                        200
# 18                        200
# 38                        200
# 20                        200
# 10                        200
# 9                         200
# 54                        200
# 11                        200
# 56                        200
#
#                                                params  ...  split1_test_score  \
# 72  {'forest__max_depth': 100, 'forest__max_sample...  ...           0.649362
# 74  {'forest__max_depth': 100, 'forest__max_sample...  ...           0.651562
# 73  {'forest__max_depth': 100, 'forest__max_sample...  ...           0.641003
# 46  {'forest__max_depth': 75, 'forest__max_samples...  ...           0.643643
# 45  {'forest__max_depth': 75, 'forest__max_samples...  ...           0.645403
# 47  {'forest__max_depth': 75, 'forest__max_samples...  ...           0.646722
# 64  {'forest__max_depth': 100, 'forest__max_sample...  ...           0.644523
# 63  {'forest__max_depth': 100, 'forest__max_sample...  ...           0.642323
# 65  {'forest__max_depth': 100, 'forest__max_sample...  ...           0.644083
# 37  {'forest__max_depth': 75, 'forest__max_samples...  ...           0.638363
# 36  {'forest__max_depth': 75, 'forest__max_samples...  ...           0.634404
# 19  {'forest__max_depth': 50, 'forest__max_samples...  ...           0.637923
# 18  {'forest__max_depth': 50, 'forest__max_samples...  ...           0.635724
# 38  {'forest__max_depth': 75, 'forest__max_samples...  ...           0.638803
# 20  {'forest__max_depth': 50, 'forest__max_samples...  ...           0.636604
# 10  {'forest__max_depth': 50, 'forest__max_samples...  ...           0.631764
# 9   {'forest__max_depth': 50, 'forest__max_samples...  ...           0.625165
# 54  {'forest__max_depth': 100, 'forest__max_sample...  ...           0.626045
# 11  {'forest__max_depth': 50, 'forest__max_samples...  ...           0.630004
# 56  {'forest__max_depth': 100, 'forest__max_sample...  ...           0.630004
#
#     split2_test_score  mean_test_score  std_test_score  rank_test_score  \
# 72           0.647602         0.649362        0.001437                1
# 74           0.641003         0.647456        0.004619                2
# 73           0.644963         0.645696        0.004163                3
# 46           0.645842         0.644523        0.000950                4
# 45           0.641883         0.643936        0.001496                5
# 47           0.641003         0.643496        0.002392                6
# 64           0.638803         0.642030        0.002392                7
# 63           0.639683         0.640856        0.001097                8
# 65           0.634844         0.638510        0.004005                9
# 37           0.638363         0.637337        0.001452               10
# 36           0.635724         0.636164        0.001646               11
# 19           0.631324         0.635430        0.002926               12
# 18           0.636164         0.634990        0.001360               13
# 38           0.636164         0.634551        0.004286               14
# 20           0.630444         0.633817        0.002548               15
# 10           0.628685         0.630004        0.001295               16
# 9            0.629564         0.627511        0.001808               17
# 54           0.627805         0.626778        0.000748               18
# 11           0.623405         0.626485        0.002712               19
# 56           0.622085         0.625605        0.003292               20
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 72            0.915970            0.907611            0.921249
# 74            0.823141            0.822481            0.826221
# 73            0.883854            0.875935            0.888033
# 46            0.821161            0.820282            0.824681
# 45            0.857237            0.846018            0.860757
# 47            0.777167            0.775627            0.780246
# 64            0.812802            0.815662            0.820722
# 63            0.849098            0.842719            0.849758
# 65            0.768148            0.769908            0.779806
# 37            0.767268            0.774307            0.776507
# 36            0.794545            0.798944            0.800704
# 19            0.745491            0.742411            0.743731
# 18            0.765728            0.760449            0.763528
# 38            0.733172            0.736692            0.744611
# 20            0.710515            0.708975            0.711395
# 10            0.708095            0.710075            0.716674
# 9             0.720414            0.724153            0.734052
# 54            0.705895            0.714474            0.712055
# 11            0.680378            0.685878            0.688517
# 56            0.671579            0.681258            0.676859
#
#     mean_train_score  std_train_score
# 72          0.914944         0.005615
# 74          0.823948         0.001630
# 73          0.882607         0.005017
# 46          0.822041         0.001901
# 45          0.854671         0.006285
# 47          0.777680         0.001920
# 64          0.816395         0.003274
# 63          0.847192         0.003174
# 65          0.772621         0.005132
# 37          0.772694         0.003940
# 36          0.798064         0.002590
# 19          0.743877         0.001262
# 18          0.763235         0.002165
# 38          0.738158         0.004784
# 20          0.710295         0.001000
# 10          0.711615         0.003668
# 9           0.726206         0.005754
# 54          0.710808         0.003612
# 11          0.684924         0.003390
# 56          0.676565         0.003957
#
# [20 rows x 21 columns]

# %%
gridsearch_forest_df2['train_test_diff'] = gridsearch_forest_df2['mean_train_score'] - gridsearch_forest_df2['mean_test_score']

#sort by difference btwn train vs test scores
min_overfitting = gridsearch_forest_df2.sort_values(by=['train_test_diff'], ascending=True)

#Remove unneeded columns
min_overfitting = min_overfitting[['train_test_diff', 'mean_test_score', 'mean_train_score', 'param_forest__max_depth', 'param_forest__max_samples', 'param_forest__min_samples_leaf', 'param_forest__min_samples_split']]

# %%
min_overfitting = min_overfitting.loc[min_overfitting['train_test_diff'] < 0.05]
min_overfitting.sort_values(by=['mean_test_score'], ascending=False).head(25)
# Out:
#     train_test_diff  mean_test_score  mean_train_score  \
# 77         0.031530         0.625458          0.656988
# 75         0.033363         0.624138          0.657501
# 76         0.033363         0.624138          0.657501
# 49         0.031163         0.624138          0.655301
# 48         0.031163         0.624138          0.655301
# 50         0.030796         0.623845          0.654641
# 29         0.042748         0.621059          0.663807
# 23         0.024124         0.620326          0.644449
# 21         0.025444         0.619886          0.645329
# 22         0.025444         0.619886          0.645329
# 0          0.040695         0.619299          0.659994
# 1          0.035269         0.618566          0.653835
# 2          0.026543         0.615926          0.642470
# 67         0.015618         0.614606          0.630224
# 66         0.015618         0.614606          0.630224
# 68         0.015838         0.614460          0.630298
# 41         0.015985         0.614313          0.630298
# 39         0.015691         0.614313          0.630004
# 40         0.015691         0.614313          0.630004
# 14         0.013638         0.613726          0.627365
# 13         0.014078         0.612700          0.626778
# 12         0.014078         0.612700          0.626778
# 58        -0.000220         0.596568          0.596348
# 31        -0.000220         0.596568          0.596348
# 3         -0.000220         0.596568          0.596348
#
#    param_forest__max_depth param_forest__max_samples  \
# 77                     100                       0.8
# 75                     100                       0.8
# 76                     100                       0.8
# 49                      75                       0.8
# 48                      75                       0.8
# 50                      75                       0.8
# 29                      75                       0.2
# 23                      50                       0.8
# 21                      50                       0.8
# 22                      50                       0.8
# 0                       50                       0.2
# 1                       50                       0.2
# 2                       50                       0.2
# 67                     100                       0.5
# 66                     100                       0.5
# 68                     100                       0.5
# 41                      75                       0.5
# 39                      75                       0.5
# 40                      75                       0.5
# 14                      50                       0.5
# 13                      50                       0.5
# 12                      50                       0.5
# 58                     100                       0.2
# 31                      75                       0.2
# 3                       50                       0.2
#
#    param_forest__min_samples_leaf param_forest__min_samples_split
# 77                              5                              25
# 75                              5                               2
# 76                              5                               5
# 49                              5                               5
# 48                              5                               2
# 50                              5                              25
# 29                              1                              25
# 23                              5                              25
# 21                              5                               2
# 22                              5                               5
# 0                               1                               2
# 1                               1                               5
# 2                               1                              25
# 67                              5                               5
# 66                              5                               2
# 68                              5                              25
# 41                              5                              25
# 39                              5                               2
# 40                              5                               5
# 14                              5                              25
# 13                              5                               5
# 12                              5                               2
# 58                              5                               5
# 31                              5                               5
# 3                               5                               2

# %% [markdown]
# * max_depth in 75 to >100 range
# * max_samples around 0.8
# * min_samples_leaf >5, <20
# * min_samples_split >2, <25

# %%
#Create pipeline - Lock in parameters based on previous model

#Remove entropy based on previous results
#auto & sqrt are the same according to docs
pipe_forest3 = Pipeline([('forest', RandomForestClassifier(random_state=70, n_jobs=-1, bootstrap=True, criterion='gini', max_features='sqrt'))])

# %%
# Create the grid parameter
grid_forest3 = [{'forest__n_estimators': [200],
             'forest__max_depth': [75, 85, 110, 150],
             'forest__min_samples_split': [4, 7, 10, 15], 
             'forest__min_samples_leaf': [7, 10, 12, 15], 
             'forest__max_samples': [.7, .8, .9]
             }]

# Create the grid, with "pipe" as the estimator
gridsearch_forest3 = GridSearchCV(estimator=pipe_forest3, 
                          param_grid=grid_forest3,
                          scoring='accuracy',
                          return_train_score=True, #Include training results in cv_results
                          cv=3, #Use 3 folds in CV process
                          n_jobs=-1, #Use paralell computing
                          verbose=4) #Give updates on progress during fitting

# %%
gridsearch_forest3.fit(tf_idf_data_train, y_train)
# Out:
# Fitting 3 folds for each of 192 candidates, totalling 576 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 576 out of 576 | elapsed:  3.9min finished
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('forest',
#                                         RandomForestClassifier(max_features='sqrt',
#                                                                n_jobs=-1,
#                                                                random_state=70))]),
#              n_jobs=-1,
#              param_grid=[{'forest__max_depth': [75, 85, 110, 150],
#                           'forest__max_samples': [0.7, 0.8, 0.9],
#                           'forest__min_samples_leaf': [7, 10, 12, 15],
#                           'forest__min_samples_split': [4, 7, 10, 15],
#                           'forest__n_estimators': [200]}],
#              return_train_score=True, scoring='accuracy', verbose=4)

# %%
gridsearch_forest3.best_params_
# Out:
# {'forest__max_depth': 75,
#  'forest__max_samples': 0.9,
#  'forest__min_samples_leaf': 7,
#  'forest__min_samples_split': 15,
#  'forest__n_estimators': 200}

# %%
gridsearch_forest_df3 = pd.DataFrame.from_dict(gridsearch_forest3.cv_results_)
gridsearch_forest_df3.sort_values(by=['mean_test_score'], ascending=False).head(20)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 35        4.391086      0.073613         0.143997        0.049403
# 83        4.343822      0.042848         0.108909        0.001129
# 179       4.449345      0.098457         0.143732        0.046444
# 131       4.338524      0.186840         0.109974        0.002477
# 128       3.856939      0.289372         0.144278        0.049895
# 81        4.319267      0.186667         0.143671        0.049532
# 32        4.031406      0.087684         0.144441        0.049655
# 33        4.321893      0.106970         0.109104        0.001041
# 80        4.004467      0.074456         0.110058        0.001762
# 129       4.326383      0.083914         0.111555        0.001731
# 34        4.357767      0.218964         0.143000        0.048493
# 82        4.353540      0.347741         0.108686        0.000711
# 130       4.355691      0.273821         0.111500        0.004759
# 176       4.028181      0.164056         0.109800        0.000476
# 177       4.250524      0.057051         0.108781        0.000200
# 178       4.224033      0.317358         0.109494        0.001763
# 114       3.911816      0.057985         0.142905        0.048610
# 113       3.915789      0.138119         0.143311        0.048514
# 112       3.465919      0.219614         0.143538        0.047121
# 65        3.786072      0.135051         0.143287        0.048852
#
#     param_forest__max_depth param_forest__max_samples  \
# 35                       75                       0.9
# 83                       85                       0.9
# 179                     150                       0.9
# 131                     110                       0.9
# 128                     110                       0.9
# 81                       85                       0.9
# 32                       75                       0.9
# 33                       75                       0.9
# 80                       85                       0.9
# 129                     110                       0.9
# 34                       75                       0.9
# 82                       85                       0.9
# 130                     110                       0.9
# 176                     150                       0.9
# 177                     150                       0.9
# 178                     150                       0.9
# 114                     110                       0.8
# 113                     110                       0.8
# 112                     110                       0.8
# 65                       85                       0.8
#
#     param_forest__min_samples_leaf param_forest__min_samples_split  \
# 35                               7                              15
# 83                               7                              15
# 179                              7                              15
# 131                              7                              15
# 128                              7                               4
# 81                               7                               7
# 32                               7                               4
# 33                               7                               7
# 80                               7                               4
# 129                              7                               7
# 34                               7                              10
# 82                               7                              10
# 130                              7                              10
# 176                              7                               4
# 177                              7                               7
# 178                              7                              10
# 114                              7                              10
# 113                              7                               7
# 112                              7                               4
# 65                               7                               7
#
#     param_forest__n_estimators  \
# 35                         200
# 83                         200
# 179                        200
# 131                        200
# 128                        200
# 81                         200
# 32                         200
# 33                         200
# 80                         200
# 129                        200
# 34                         200
# 82                         200
# 130                        200
# 176                        200
# 177                        200
# 178                        200
# 114                        200
# 113                        200
# 112                        200
# 65                         200
#
#                                                 params  ...  \
# 35   {'forest__max_depth': 75, 'forest__max_samples...  ...
# 83   {'forest__max_depth': 85, 'forest__max_samples...  ...
# 179  {'forest__max_depth': 150, 'forest__max_sample...  ...
# 131  {'forest__max_depth': 110, 'forest__max_sample...  ...
# 128  {'forest__max_depth': 110, 'forest__max_sample...  ...
# 81   {'forest__max_depth': 85, 'forest__max_samples...  ...
# 32   {'forest__max_depth': 75, 'forest__max_samples...  ...
# 33   {'forest__max_depth': 75, 'forest__max_samples...  ...
# 80   {'forest__max_depth': 85, 'forest__max_samples...  ...
# 129  {'forest__max_depth': 110, 'forest__max_sample...  ...
# 34   {'forest__max_depth': 75, 'forest__max_samples...  ...
# 82   {'forest__max_depth': 85, 'forest__max_samples...  ...
# 130  {'forest__max_depth': 110, 'forest__max_sample...  ...
# 176  {'forest__max_depth': 150, 'forest__max_sample...  ...
# 177  {'forest__max_depth': 150, 'forest__max_sample...  ...
# 178  {'forest__max_depth': 150, 'forest__max_sample...  ...
# 114  {'forest__max_depth': 110, 'forest__max_sample...  ...
# 113  {'forest__max_depth': 110, 'forest__max_sample...  ...
# 112  {'forest__max_depth': 110, 'forest__max_sample...  ...
# 65   {'forest__max_depth': 85, 'forest__max_samples...  ...
#
#      split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 35            0.614166           0.615926         0.613873        0.001808
# 83            0.614166           0.615926         0.613726        0.002000
# 179           0.614166           0.615926         0.613726        0.002000
# 131           0.614166           0.615926         0.613726        0.002000
# 128           0.614166           0.615926         0.613286        0.002590
# 81            0.614166           0.615926         0.613286        0.002590
# 32            0.614166           0.615926         0.613286        0.002590
# 33            0.614166           0.615926         0.613286        0.002590
# 80            0.614166           0.615926         0.613286        0.002590
# 129           0.614166           0.615926         0.613286        0.002590
# 34            0.614166           0.615926         0.613286        0.002590
# 82            0.614166           0.615926         0.613286        0.002590
# 130           0.614166           0.615926         0.613286        0.002590
# 176           0.614166           0.615926         0.613286        0.002590
# 177           0.614166           0.615926         0.613286        0.002590
# 178           0.614166           0.615926         0.613286        0.002590
# 114           0.615046           0.612846         0.611673        0.003338
# 113           0.615046           0.612846         0.611673        0.003338
# 112           0.615046           0.612846         0.611673        0.003338
# 65            0.615046           0.612846         0.611673        0.003338
#
#      rank_test_score  split0_train_score  split1_train_score  \
# 35                 1            0.628465            0.634844
# 83                 2            0.628245            0.635064
# 179                2            0.628245            0.635064
# 131                2            0.628245            0.635064
# 128                5            0.630884            0.635284
# 81                 5            0.630884            0.635064
# 32                 5            0.630664            0.634844
# 33                 5            0.630664            0.634844
# 80                 5            0.630884            0.635064
# 129                5            0.630884            0.635284
# 34                 5            0.630664            0.634844
# 82                 5            0.630884            0.635064
# 130                5            0.630884            0.635284
# 176                5            0.630884            0.635284
# 177                5            0.630884            0.635284
# 178                5            0.630884            0.635284
# 114               17            0.620985            0.633304
# 113               17            0.620985            0.633304
# 112               17            0.620985            0.633304
# 65                17            0.620985            0.633524
#
#      split2_train_score  mean_train_score  std_train_score
# 35             0.630004          0.631104         0.002718
# 83             0.629784          0.631031         0.002920
# 179            0.629784          0.631031         0.002920
# 131            0.629784          0.631031         0.002920
# 128            0.630004          0.632057         0.002309
# 81             0.630004          0.631984         0.002207
# 32             0.629784          0.631764         0.002207
# 33             0.629784          0.631764         0.002207
# 80             0.630004          0.631984         0.002207
# 129            0.630004          0.632057         0.002309
# 34             0.629784          0.631764         0.002207
# 82             0.630004          0.631984         0.002207
# 130            0.630004          0.632057         0.002309
# 176            0.630004          0.632057         0.002309
# 177            0.630004          0.632057         0.002309
# 178            0.630004          0.632057         0.002309
# 114            0.622965          0.625752         0.005401
# 113            0.622965          0.625752         0.005401
# 112            0.622965          0.625752         0.005401
# 65             0.622965          0.625825         0.005504
#
# [20 rows x 21 columns]

# %%
# Create the grid parameter
grid_forest = [{'forest__n_estimators': [200],
             'forest__max_depth': [1, 5, 15, 25, 50],
             'forest__min_samples_split': [2, 5, 10, 25, 50], 
             'forest__min_samples_leaf': [1, 3, 5, 10, 25], 
             'forest__criterion': ['gini', 'entropy'],
             'forest__max_features': ['auto', 'sqrt', 'log2'],
             'forest__max_samples': [None, .2, .5, .8]
             }]

# Create the grid, with "pipe" as the estimator
gridsearch_forest = RandomizedSearchCV(estimator=pipe_forest, 
                          param_distributions=grid_forest, 
                          return_train_score=True, #Include training results in cv_results
                          cv=5, #Use 5 folds in CV process
                          n_iter=500, #Try 500 hyperparameter combinations
                          n_jobs=-1, #Use paralell computing
                          verbose=8) #Give updates on progress during fitting
